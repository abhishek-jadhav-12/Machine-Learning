# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

cup = pd.read_parquet("../data/raw/cup_series.parquet")
nxs = pd.read_parquet("../data/raw/nxs_series.parquet")
truck = pd.read_parquet("../data/raw/truck_series.parquet")

print(cup.shape)
print(nxs.shape)
print(truck.shape)
# Out:
# (100782, 21)
# (54884, 21)
# (25951, 21)

# %%
cup.head()
# Out:
#    Season  Race               Track                             Name  Length  \
# 0    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
# 1    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
# 2    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
# 3    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
# 4    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
#
#   Surface  Finish  Start Car       Driver  ... Pts   Laps   Led   Status  \
# 0    dirt       1   12.0  34    Jim Roper  ... NaN  197.0  47.0  running
# 1    dirt       2    5.0  47  Fonty Flock  ... NaN    NaN   0.0  running
# 2    dirt       3    3.0  22    Red Byron  ... NaN    NaN   0.0  running
# 3    dirt       4   14.0   2     Sam Rice  ... NaN    NaN   0.0  running
# 4    dirt       5    2.0  90    Tim Flock  ... NaN    NaN   0.0  running
#
#                     Team  S1  S2  S3  Rating  Win
# ...

# %%
cup.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100782 entries, 0 to 100781
# Data columns (total 21 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Season   100782 non-null  int32
#  1   Race     100782 non-null  int32
#  2   Track    100782 non-null  str
#  3   Name     100782 non-null  str
#  4   Length   100628 non-null  float64
#  5   Surface  100628 non-null  str
#  6   Finish   100782 non-null  int32
#  7   Start    97703 non-null   float64
#  8   Car      100782 non-null  str
#  9   Driver   100782 non-null  str
#  10  Make     100782 non-null  str
#  11  Pts      90586 non-null   float64
#  12  Laps     98543 non-null   float64
#  13  Led      100781 non-null  float64
#  14  Status   100782 non-null  str
#  15  Team     100782 non-null  str
#  16  S1       3050 non-null    float64
#  17  S2       3050 non-null    float64
#  18  S3       0 non-null       float64
#  19  Rating   31451 non-null   float64
# ...

# %%
cup.columns
# Out:
# Index(['Season', 'Race', 'Track', 'Name', 'Length', 'Surface', 'Finish',
#        'Start', 'Car', 'Driver', 'Make', 'Pts', 'Laps', 'Led', 'Status',
#        'Team', 'S1', 'S2', 'S3', 'Rating', 'Win'],
#       dtype='str')

# %%
cup.columns.tolist()
# Out:
# ['Season',
#  'Race',
#  'Track',
#  'Name',
#  'Length',
#  'Surface',
#  'Finish',
#  'Start',
#  'Car',
#  'Driver',
#  'Make',
#  'Pts',
#  'Laps',
#  'Led',
#  'Status',
#  'Team',
#  'S1',
#  'S2',
#  'S3',
#  'Rating',
#  'Win']

# %%
nxs.columns.tolist()
# Out:
# ['Season',
#  'Race',
#  'Track',
#  'Name',
#  'Length',
#  'Surface',
#  'Finish',
#  'Start',
#  'Car',
#  'Driver',
#  'Make',
#  'Pts',
#  'Laps',
#  'Led',
#  'Status',
#  'Team',
#  'S1',
#  'S2',
#  'S3',
#  'Rating',
#  'Win']

# %%
truck.columns.tolist()
# Out:
# ['Season',
#  'Race',
#  'Track',
#  'Name',
#  'Length',
#  'Surface',
#  'Finish',
#  'Start',
#  'Car',
#  'Driver',
#  'Make',
#  'Pts',
#  'Laps',
#  'Led',
#  'Status',
#  'Team',
#  'S1',
#  'S2',
#  'S3',
#  'Rating',
#  'Win']

# %%
df = pd.read_parquet("../data/processed/merged_dataset.parquet")

# %%
print("Dataset Shape:")
print(df.shape)

print("\nFirst 5 Rows:")
display(df.head())
# Out:
# Dataset Shape:
# (181617, 22)
#
# First 5 Rows:
#    Season  Race               Track                             Name  Length  \
# 0    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
# 1    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
# 2    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
# 3    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
# 4    1949     1  Charlotte Speedway  150 Miles at Charlotte Speedway    0.75
#
#   Surface  Finish  Start Car       Driver  ...   Laps   Led   Status  \
# 0    dirt     1.0   12.0  34    Jim Roper  ...  197.0  47.0  running
# 1    dirt     2.0    5.0  47  Fonty Flock  ...    NaN   0.0  running
# 2    dirt     3.0    3.0  22    Red Byron  ...    NaN   0.0  running
# 3    dirt     4.0   14.0   2     Sam Rice  ...    NaN   0.0  running
# 4    dirt     5.0    2.0  90    Tim Flock  ...    NaN   0.0  running
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 181617 entries, 0 to 181616
# Data columns (total 22 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Season   181617 non-null  int32
#  1   Race     181617 non-null  int32
#  2   Track    181617 non-null  str
#  3   Name     181617 non-null  str
#  4   Length   180601 non-null  float64
#  5   Surface  180601 non-null  str
#  6   Finish   181613 non-null  float64
#  7   Start    178537 non-null  float64
#  8   Car      181617 non-null  str
#  9   Driver   181617 non-null  str
#  10  Make     181617 non-null  str
#  11  Pts      171421 non-null  float64
#  12  Laps     179378 non-null  float64
#  13  Led      180997 non-null  float64
#  14  Status   181617 non-null  str
#  15  Team     181617 non-null  str
#  16  S1       7830 non-null    float64
#  17  S2       7831 non-null    float64
#  18  S3       0 non-null       float64
#  19  Rating   78147 non-null   float64
# ...

# %%
missing = df.isnull().sum()

missing = missing[missing > 0]

missing.sort_values(ascending=False)
# Out:
# S3         181617
# S1         173787
# S2         173786
# Rating     103470
# Pts         10196
# Start        3080
# Laps         2239
# Length       1016
# Surface      1016
# Led           620
# Finish          4
# Win             4
# dtype: int64

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 0

# %%
df.describe()
# Out:
#               Season           Race         Length         Finish  \
# count  181617.000000  181617.000000  180601.000000  181613.000000
# mean     1996.946580      17.512623       1.364013      19.398727
# std        20.248056      11.032302       0.752272      11.577254
# min      1949.000000       1.000000       0.200000       1.000000
# 25%      1984.000000       8.000000       0.686000      10.000000
# 50%      2001.000000      17.000000       1.366000      19.000000
# 75%      2013.000000      25.000000       1.990000      29.000000
# max      2026.000000      62.000000       4.170000      82.000000
#
#                Start            Pts           Laps            Led  \
# count  178537.000000  171421.000000  179378.000000  180997.000000
# mean       19.363051      97.327830     196.757679       6.303541
# std        11.655440     192.833795     119.497006      27.017471
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
categorical_columns = [
    "Driver",
    "Track",
    "Team",
    "Make",
    "Surface",
    "Series",
    "Status"
]

for column in categorical_columns:
    print(f"\n{column}")
    print(df[column].nunique())
# Out:
# Driver
# 4372
#
# Track
# 212
#
# Team
# 2777
#
# Make
# 32
#
# Surface
# 3
#
# Series
# 3
#
# Status
# 231

# %%
df["Make"].value_counts()
# Out:
# Make
# Chevrolet                    74843
# Ford                         44646
# Toyota                       16496
# Dodge                        13748
# Pontiac                      11790
# Oldsmobile                    6313
# Buick                         4659
# Plymouth                      3557
# Mercury                       2224
# Hudson                        1148
# Chrysler                       660
# -                              575
# Nash Motor Company             179
# Studebaker                     176
# RAM                            165
# Lincoln                        145
# Kaiser                          82
# Matador                         54
# Packard Motor Car Company       51
# Cadillac                        40
# Jaguar                          20
# Morris Garage                   13
# American Motors Company         12
# GMC                              6
# Sprite                           4
# Austin-Healey                    3
# ...

# %%
df["Series"].value_counts()
# Out:
# Series
# Cup      100782
# NXS       54884
# Truck     25951
# Name: count, dtype: int64

# %%
df["Surface"].value_counts()
# Out:
# Surface
# paved    156665
# dirt      12274
# road      11662
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))

plt.hist(df["Rating"], bins=30)

plt.title("Distribution of Driver Rating")

plt.xlabel("Rating")

plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.hist(df["Finish"], bins=40)

plt.title("Finish Position")

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.hist(df["Start"], bins=40)

plt.title("Starting Position")

plt.show()

# %%
numeric_df = df.select_dtypes(include="number")

correlation = numeric_df.corr()

correlation
# Out:
#               Season          Race        Length    Finish     Start  \
# Season  1.000000e+00 -1.960304e-01  2.555634e-01  0.102543  0.104100
# Race   -1.960304e-01  1.000000e+00 -1.636462e-01 -0.015142 -0.013577
# Length  2.555634e-01 -1.636462e-01  1.000000e+00  0.127179  0.129174
# Finish  1.025433e-01 -1.514221e-02  1.271787e-01  1.000000  0.472644
# Start   1.040996e-01 -1.357723e-02  1.291741e-01  0.472644  1.000000
# Pts    -3.583128e-01  9.969722e-02 -3.598039e-02 -0.250608 -0.104660
# Laps    1.470103e-02  6.533018e-02 -3.937591e-01 -0.349239 -0.085562
# Led    -2.731873e-02  1.577844e-02 -7.255506e-02 -0.259893 -0.269501
# S1     -1.424584e-15  7.126508e-16  1.260775e-16  0.132845  0.366081
# S2     -1.406451e-06  1.127648e-05  3.139007e-06  0.157113  0.234017
# S3               NaN           NaN           NaN       NaN       NaN
# Rating -1.085949e-02 -3.375316e-03 -1.257160e-03 -0.821751 -0.707772
# Win    -1.890882e-02  4.024448e-03 -1.745510e-02 -0.267700 -0.181983
#
# ...
